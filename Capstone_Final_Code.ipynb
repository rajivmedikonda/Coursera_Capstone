# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# ...

# %%
CLIENT_ID = 'V2OXGJJ0MS3TJ2NZV0PLJGFT4A1S5Z41UI3NMC4DHED033JK' # your Foursquare ID
CLIENT_SECRET = 'CQSCDFM4TTVR5HVUXJCMOIAOA4MXTZCBS2L3HJSCGA1YZ3NA' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 300
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: V2OXGJJ0MS3TJ2NZV0PLJGFT4A1S5Z41UI3NMC4DHED033JK
# CLIENT_SECRET:CQSCDFM4TTVR5HVUXJCMOIAOA4MXTZCBS2L3HJSCGA1YZ3NA

# %%
address = '2200 Hilltop Mall Rd, Richmond, CA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 37.9815472 -122.3245298

# %%
Italian_search_query = 'Italian'
radius = 500000
print(Italian_search_query + ' .... OK!')

Italian_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, Italian_search_query, radius, LIMIT)
Italian_url

italian_results = requests.get(Italian_url).json()
italian_results

# assign relevant part of JSON to venues
venues = italian_results['response']['venues']

# tranform venues into a dataframe
italian_dataframe = json_normalize(venues)


# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in italian_dataframe.columns if col.startswith('location.')] + ['id']
italian_dataframe_filtered = italian_dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
italian_dataframe_filtered['categories'] = italian_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
italian_dataframe_filtered.columns = [column.split('.')[-1] for column in italian_dataframe_filtered.columns]
# Out:
# Italian .... OK!

# %%
indian_search_query = 'indian'
radius = 500000
print(indian_search_query + ' .... OK!')

indian_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, indian_search_query, radius, LIMIT)
indian_url

indian_results = requests.get(indian_url).json()
indian_results

# assign relevant part of JSON to venues
venues = indian_results['response']['venues']

# tranform venues into a dataframe
indian_dataframe = json_normalize(venues)


# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in indian_dataframe.columns if col.startswith('location.')] + ['id']
indian_dataframe_filtered = indian_dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
indian_dataframe_filtered['categories'] = indian_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
indian_dataframe_filtered.columns = [column.split('.')[-1] for column in indian_dataframe_filtered.columns]

indian_dataframe_filtered
# Out:
# indian .... OK!
#                                           name               categories  \
# 0                             Indian Rock Park                     Park
# 1                           Kasa Indian Eatery        Indian Restaurant
# 2     Kennedy's Irish Pub & Indian Curry House                Irish Pub
# 3                     Pakwan Indian Restaurant        Indian Restaurant
# 4                        Wazwan Indian Cuisine        Indian Restaurant
# 5            JotMahal Palace of Indian Cuisine        Indian Restaurant
# 6                                  Indian Oven        Indian Restaurant
# 7            Indian Valley Open Space Preserve                    Trail
# 8                    Indian Valley Golf Course              Golf Course
# 9                  Haweli North Indian Cuisine        Indian Restaurant
# 10                    Haweli Indian Restaurant                     Food
# 11             Indian Valley Elementary School                   School
# ...

# %%
mexican_search_query = 'mexican'
radius = 500000
print(mexican_search_query + ' .... OK!')

mexican_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, mexican_search_query, radius, LIMIT)
mexican_url

mexican_results = requests.get(mexican_url).json()
mexican_results

# assign relevant part of JSON to venues
venues = mexican_results['response']['venues']

# tranform venues into a dataframe
mexican_dataframe = json_normalize(venues)


# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in mexican_dataframe.columns if col.startswith('location.')] + ['id']
mexican_dataframe_filtered = mexican_dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
mexican_dataframe_filtered['categories'] = mexican_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
mexican_dataframe_filtered.columns = [column.split('.')[-1] for column in mexican_dataframe_filtered.columns]

mexican_dataframe_filtered
# Out:
# mexican .... OK!
#                                       name            categories  \
# 0                   Chipotle Mexican Grill    Mexican Restaurant
# 1                   Papalote Mexican Grill    Mexican Restaurant
# 2                   Chipotle Mexican Grill    Mexican Restaurant
# 3                   Chipotle Mexican Grill    Mexican Restaurant
# 4                   Chipotle Mexican Grill    Mexican Restaurant
# 5                   Colibrí Mexican Bistro    Mexican Restaurant
# 6                     Caramba Mexican Food    Mexican Restaurant
# 7                   Papalote Mexican Grill    Mexican Restaurant
# 8           Don Ramon's Mexican Restaurant    Mexican Restaurant
# 9                   Chipotle Mexican Grill    Mexican Restaurant
# 10                    Lucinda Mexican Food    Mexican Restaurant
# 11                  Chipotle Mexican Grill    Mexican Restaurant
# 12              Celia's Mexican Restaurant    Mexican Restaurant
# ...

# %%
mall_search_query = 'mall'
radius = 500000
print(mall_search_query + ' .... OK!')

mall_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, mall_search_query, radius, LIMIT)
mall_url

mall_results = requests.get(mall_url).json()
mall_results

# assign relevant part of JSON to venues
venues = mall_results['response']['venues']

# tranform venues into a dataframe
mall_dataframe = json_normalize(venues)


# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in mall_dataframe.columns if col.startswith('location.')] + ['id']
mall_dataframe_filtered = mall_dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
mall_dataframe_filtered['categories'] = mall_dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
mall_dataframe_filtered.columns = [column.split('.')[-1] for column in mall_dataframe_filtered.columns]
# Out:
# mall .... OK!

# %%
# latitude = italian_dataframe_filtered['lat'].median()
# longitude = italian_dataframe_filtered['lng'].median()

map_sf = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, name, categories in zip(italian_dataframe_filtered['lat'], italian_dataframe_filtered['lng'], italian_dataframe_filtered['name'], italian_dataframe_filtered['categories']):
    label = '{}, {}'.format(name, categories)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_sf)  

#add markers to map
for lat, lng, name, categories in zip(indian_dataframe_filtered['lat'], indian_dataframe_filtered['lng'], indian_dataframe_filtered['name'], indian_dataframe_filtered['categories']):
    label = '{}, {}'.format(name, categories)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_sf)  
    
# add markers to map
for lat, lng, name, categories in zip(mexican_dataframe_filtered['lat'], mexican_dataframe_filtered['lng'], mexican_dataframe_filtered['name'], mexican_dataframe_filtered['categories']):
    label = '{}, {}'.format(name, categories)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_sf) 

# add markers to map
for lat, lng, name, categories in zip(mall_dataframe_filtered['lat'], mall_dataframe_filtered['lng'], mall_dataframe_filtered['name'], mall_dataframe_filtered['categories']):
    label = '{}, {}'.format(name, categories)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=20,
        popup=label,
        color='yellow',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.1,
        parse_html=False).add_to(map_sf)
    
map_sf
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
